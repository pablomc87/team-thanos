# %%
import pandas as pd

# %%
data = pd.read_csv('GHG_projections_2021_EEA.csv')

# %%
data
# Out:
#        CountryCode  Year  SubmissionYear                          Category  \
# 0               BE  2018            2021            Total excluding LULUCF
# 1               BE  2019            2021            Total excluding LULUCF
# 2               BE  2020            2021            Total excluding LULUCF
# 3               BE  2021            2021            Total excluding LULUCF
# 4               BE  2022            2021            Total excluding LULUCF
# ...            ...   ...             ...                               ...
# 133457       EU 27  2036            2021  Indirect CO2 (if available) (10)
# 133458       EU 27  2037            2021  Indirect CO2 (if available) (10)
# 133459       EU 27  2038            2021  Indirect CO2 (if available) (10)
# 133460       EU 27  2039            2021  Indirect CO2 (if available) (10)
# 133461       EU 27  2040            2021  Indirect CO2 (if available) (10)
#
# ...

# %%
data['Gas'].unique()
# Out:
# array(['Total GHG emissions (ktCO2e)', 'ETS emissions (ktCO2e)',
#        'ESR emissions (ktCO2e)'], dtype=object)
