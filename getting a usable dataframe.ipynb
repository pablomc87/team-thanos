# %%
import pandas as pd

# %%
GHG_projections = pd.read_csv('GHG_projections_2021_EEA.csv')

# %%
GHG_projections.Category.unique()
# Out:
# array(['Total excluding LULUCF',
#        'Total excluding LULUCF (incl. Int. Aviation)', '1. Energy',
#        '1.A.1. Energy industries',
#        '1.A.2. Manufacturing industries and construction',
#        '1.A.3. Transport', '1.A.3.a. Domestic aviation',
#        '1.A.3.b. Road transportation', '1.A.3.c. Railways',
#        '1.A.3.d. Domestic navigation', '1.A.3.e. Other transportation',
#        '1.A.4. Other sectors', '1.A.5. Other',
#        '1.B. Fugitive emissions from fuels',
#        '1.C. CO2 transport and storage', '2. Industrial processes',
#        '3. Agriculture', '5. Waste',
#        '4. Land Use, Land-Use Change and Forestry (LULUCF, reported emissions and removals) (9)',
#        '4.A. Forest land', '4.B. Cropland', '4.C. Grassland',
#        '4.D. Wetlands', '4.E. Settlements', '4.F. Other Land',
#        '4.G. Harvested wood products', '4.H. Other', 'IB.Aviation',
#        'IB.Navigation', 'Indirect CO2 (if available) (10)'], dtype=object)

# %%
GHG_projections.CountryCode.unique()
# Out:
# array(['BE', 'AT', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR',
#        'GR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'PL',
#        'PT', 'RO', 'SE', 'SI', 'SK', 'CH', 'IS', 'NO', 'EU 27'],
#       dtype=object)

# %%
GHG_projections.Year.unique()
# Out:
# array([2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028,
#        2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039,
#        2040, 2015, 2016, 2017, 2050], dtype=int64)

# %%
GHG_projections.Gas.unique()
# Out:
# array(['Total GHG emissions (ktCO2e)', 'ETS emissions (ktCO2e)',
#        'ESR emissions (ktCO2e)'], dtype=object)

# %%
# WEM == 'With Existing Measures'
GHG_projections_Total = GHG_projections[(GHG_projections['Gas']=='Total GHG emissions (ktCO2e)')&(GHG_projections['Scenario']=='WEM')]

# %%
GHG_projections_Total_FR = GHG_projections_Total[GHG_projections_Total['CountryCode'] == 'FR']

# %%
GHG_projections_Total_Energy = GHG_projections_Total[GHG_projections_Total['Category']=='1. Energy']

# %%
del GHG_projections_Total_Energy['SubmissionYear']
del GHG_projections_Total_Energy['Category']
del GHG_projections_Total_Energy['Scenario']
del GHG_projections_Total_Energy['Gas']
del GHG_projections_Total_Energy['Reported Value']
del GHG_projections_Total_Energy['RY calibration']

# %%
GHG_projections_Total_Energy.columns
# Out:
# Index(['CountryCode', 'Year', 'Final/Gap-filled'], dtype='object')

# %%
GHG_projections_Total_Energy_final = GHG_projections_Total_Energy.rename(columns = {'Final/Gap-filled':'Total GHG emissions (ktCO2e)'})

# %%
GHG_projections_Total_Energy_final = GHG_projections_Total_Energy_final.dropna(subset='Total GHG emissions (ktCO2e)')

# %%
GHG_projections_Total_Energy_final['Projection'] = 1

# %%
GHG_projections_Total_Energy_final
# Out:
#        CountryCode  Year  Total GHG emissions (ktCO2e)  Projection
# 46              BE  2018                  8.570313e+04           1
# 47              BE  2019                  8.678343e+04           1
# 48              BE  2020                  8.786373e+04           1
# 49              BE  2021                  8.875025e+04           1
# 50              BE  2022                  8.963676e+04           1
# ...            ...   ...                           ...         ...
# 129651       EU 27  2036                  2.097194e+06           1
# 129652       EU 27  2037                  2.062328e+06           1
# 129653       EU 27  2038                  2.026970e+06           1
# 129654       EU 27  2039                  1.950056e+06           1
# 129655       EU 27  2040                  1.916982e+06           1
#
# [702 rows x 4 columns]

# %%
GHG_emissions_WB = pd.read_csv('28fe4d80-cccb-42c9-b66b-5a71ce433a96_Data.csv')

# %%
GHG_emissions_WB = GHG_emissions_WB[GHG_emissions_WB['Series Name']=='Émissions totales de GES (kt d’équivalent CO2)']

# %%
GHG_emissions_WB.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '1990 [YR1990]', '2000 [YR2000]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]'],
#       dtype='object')

# %%
GHG_emissions_WB = GHG_emissions_WB.rename(columns = {'Country Name':'CountryName', 'Country Code': 'CountryCode'})

# %%
del GHG_emissions_WB['Series Code']
del GHG_emissions_WB['2019 [YR2019]']
del GHG_emissions_WB['2020 [YR2020]']
del GHG_emissions_WB['2021 [YR2021]']

# %%
GHG_emissions_WB
# Out:
#                                        Series Name          CountryName  \
# 28  Émissions totales de GES (kt d’équivalent CO2)                Monde
# 29  Émissions totales de GES (kt d’équivalent CO2)            Allemagne
# 30  Émissions totales de GES (kt d’équivalent CO2)             Belgique
# 31  Émissions totales de GES (kt d’équivalent CO2)               France
# 32  Émissions totales de GES (kt d’équivalent CO2)               Italie
# 33  Émissions totales de GES (kt d’équivalent CO2)           Luxembourg
# 34  Émissions totales de GES (kt d’équivalent CO2)             Pays-Bas
# 35  Émissions totales de GES (kt d’équivalent CO2)             Danemark
# 36  Émissions totales de GES (kt d’équivalent CO2)              Irlande
# 37  Émissions totales de GES (kt d’équivalent CO2)                Grèce
# 38  Émissions totales de GES (kt d’équivalent CO2)              Espagne
# 39  Émissions totales de GES (kt d’équivalent CO2)             Portugal
# ...

# %%
GHG_emissions_WB_FR = GHG_emissions_WB[GHG_emissions_WB['CountryName']=='France']

# %%
GHG_emissions_WB
# Out:
#                                        Series Name          CountryName  \
# 28  Émissions totales de GES (kt d’équivalent CO2)                Monde
# 29  Émissions totales de GES (kt d’équivalent CO2)            Allemagne
# 30  Émissions totales de GES (kt d’équivalent CO2)             Belgique
# 31  Émissions totales de GES (kt d’équivalent CO2)               France
# 32  Émissions totales de GES (kt d’équivalent CO2)               Italie
# 33  Émissions totales de GES (kt d’équivalent CO2)           Luxembourg
# 34  Émissions totales de GES (kt d’équivalent CO2)             Pays-Bas
# 35  Émissions totales de GES (kt d’équivalent CO2)             Danemark
# 36  Émissions totales de GES (kt d’équivalent CO2)              Irlande
# 37  Émissions totales de GES (kt d’équivalent CO2)                Grèce
# 38  Émissions totales de GES (kt d’équivalent CO2)              Espagne
# 39  Émissions totales de GES (kt d’équivalent CO2)             Portugal
# ...

# %%
GHG_emissions_WB.columns
# Out:
# Index(['Series Name', 'CountryName', 'CountryCode', '1990 [YR1990]',
#        '2000 [YR2000]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
GHG_emissions_WB_melt = pd.melt(GHG_emissions_WB, id_vars=['Series Name','CountryName','CountryCode'], value_vars = ['1990 [YR1990]',
       '2000 [YR2000]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
       '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'], var_name='Year', value_name='Total GHG emissions (ktCO2e)')

# %%
del GHG_emissions_WB_melt['Series Name']

# %%
GHG_emissions_WB_melt['CountryName'].unique()
# Out:
# array(['Monde', 'Allemagne', 'Belgique', 'France', 'Italie', 'Luxembourg',
#        'Pays-Bas', 'Danemark', 'Irlande', 'Grèce', 'Espagne', 'Portugal',
#        'Autriche', 'Finlande', 'Suède', 'Chypre', 'Estonie', 'Hongrie',
#        'Lettonie', 'Lituanie', 'Malte', 'Pologne', 'République tchèque',
#        'République slovaque', 'Slovénie', 'Bulgarie', 'Roumanie',
#        'Croatie'], dtype=object)

# %%
GHG_emissions_WB_melt['CountryCode'] = 'FR'

# %%
GHG_emissions_WB_melt['Projection'] = 0

# %%
GHG_emissions_WB_melt['Year'] = GHG_emissions_WB_melt['Year'].str.split(' ').str[0]

# %%
GHG_emissions_WB_melt
# Out:
#              CountryName CountryCode  Year  Total GHG emissions (ktCO2e)  \
# 0                  Monde         WLD  1990                    29848570.0
# 1              Allemagne         DEU  1990                     1160210.0
# 2               Belgique         BEL  1990                      130730.0
# 3                 France         FRA  1990                      502750.0
# 4                 Italie         ITA  1990                      491250.0
# ..                   ...         ...   ...                           ...
# 247  République slovaque         SVK  2018                       39930.0
# 248             Slovénie         SVN  2018                       17170.0
# 249             Bulgarie         BGR  2018                       53330.0
# 250             Roumanie         ROU  2018                      109010.0
# 251              Croatie         HRV  2018                       22550.0
#
#      Projection
# 0             0
# 1             0
# 2             0
# 3             0
# ...

# %%
GHG_emissions_actual_and_proj = pd.concat([GHG_emissions_WB_melt,GHG_projections_Total_Energy_final], ignore_index=True)

# %%
GHG_emissions_actual_and_proj.CountryName.value_counts()
# Out:
# Monde                  9
# Allemagne              9
# Roumanie               9
# Bulgarie               9
# Slovénie               9
# République slovaque    9
# République tchèque     9
# Pologne                9
# Malte                  9
# Lituanie               9
# Lettonie               9
# Hongrie                9
# Estonie                9
# Chypre                 9
# Suède                  9
# Finlande               9
# Autriche               9
# Portugal               9
# Espagne                9
# Grèce                  9
# Irlande                9
# Danemark               9
# Pays-Bas               9
# Luxembourg             9
# Italie                 9
# France                 9
# Belgique               9
# Croatie                9
# Name: CountryName, dtype: int64

# %%
GHG_emissions_actual_and_proj['CountryCode'].unique()
# Out:
# array(['DEU', 'BEL', 'FRA', 'ITA', 'LUX', 'NLD', 'DNK', 'IRL', 'GRC',
#        'ESP', 'PRT', 'AUT', 'FIN', 'SWE', 'CYP', 'EST', 'HUN', 'LVA',
#        'LTU', 'MLT', 'POL', 'CZE', 'SVK', 'SVN', 'BGR', 'ROU', 'HRV',
#        'CHE', 'ISL', 'NOR', 'EU 27'], dtype=object)

# %%
import pycountry

# %%
countries_codes3 = {}
for country in pycountry.countries:
    countries_codes3[country.name] = country.alpha_3

# %%
countries_codes3
# Out:
# {'Aruba': 'ABW',
#  'Afghanistan': 'AFG',
#  'Angola': 'AGO',
#  'Anguilla': 'AIA',
#  'Åland Islands': 'ALA',
#  'Albania': 'ALB',
#  'Andorra': 'AND',
#  'United Arab Emirates': 'ARE',
#  'Argentina': 'ARG',
#  'Armenia': 'ARM',
#  'American Samoa': 'ASM',
#  'Antarctica': 'ATA',
#  'French Southern Territories': 'ATF',
#  'Antigua and Barbuda': 'ATG',
#  'Australia': 'AUS',
#  'Austria': 'AUT',
#  'Azerbaijan': 'AZE',
#  'Burundi': 'BDI',
#  'Belgium': 'BEL',
#  'Benin': 'BEN',
#  'Bonaire, Sint Eustatius and Saba': 'BES',
#  'Burkina Faso': 'BFA',
#  'Bangladesh': 'BGD',
#  'Bulgaria': 'BGR',
#  'Bahrain': 'BHR',
#  'Bahamas': 'BHS',
#  'Bosnia and Herzegovina': 'BIH',
#  'Saint Barthélemy': 'BLM',
#  'Belarus': 'BLR',
#  'Belize': 'BLZ',
#  'Bermuda': 'BMU',
#  'Bolivia, Plurinational State of': 'BOL',
#  'Brazil': 'BRA',
#  'Barbados': 'BRB',
#  'Brunei Darussalam': 'BRN',
#  'Bhutan': 'BTN',
#  'Bouvet Island': 'BVT',
#  'Botswana': 'BWA',
# ...

# %%
for key, val in countries_codes3.items():
    GHG_emissions_actual_and_proj['CountryCode'][GHG_emissions_actual_and_proj['CountryName']==key] = val
# Out:
# C:\Users\Pablo\AppData\Local\Temp/ipykernel_23856/3404115035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GHG_emissions_actual_and_proj['CountryCode'][GHG_emissions_actual_and_proj['CountryName']==key] = val
# C:\Users\Pablo\AppData\Local\Temp/ipykernel_23856/3404115035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GHG_emissions_actual_and_proj['CountryCode'][GHG_emissions_actual_and_proj['CountryName']==key] = val
# C:\Users\Pablo\AppData\Local\Temp/ipykernel_23856/3404115035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
GHG_emissions_actual_and_proj['CountryName'][GHG_emissions_actual_and_proj['CountryCode']=='EU 27'] = 'EU 27'
# Out:
# C:\Users\Pablo\AppData\Local\Temp/ipykernel_23856/1848030004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GHG_emissions_actual_and_proj['CountryName'][GHG_emissions_actual_and_proj['CountryCode']=='EU 27'] = 'EU 27'

# %%
GHG_emissions_actual_and_proj['CountryName'].isna().value_counts()
# Out:
# False    954
# Name: CountryName, dtype: int64

# %%
GHG_emissions_actual_and_proj['CountryCode'].unique()
# Out:
# array(['DEU', 'BEL', 'FRA', 'ITA', 'LUX', 'NLD', 'DNK', 'IRL', 'GRC',
#        'ESP', 'PRT', 'AUT', 'FIN', 'SWE', 'CYP', 'EST', 'HUN', 'LVA',
#        'LTU', 'MLT', 'POL', 'CZE', 'SVK', 'SVN', 'BGR', 'ROU', 'HRV',
#        'BE', 'AT', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR',
#        'GR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'PL',
#        'PT', 'RO', 'SE', 'SI', 'SK', 'CH', 'IS', 'NO', 'EU 27'],
#       dtype=object)

# %%
GHG_emissions_actual_and_proj= GHG_emissions_actual_and_proj[GHG_emissions_actual_and_proj['CountryCode']!='WLD']

# %%
GHG_emissions_actual_and_proj
# Out:
#     CountryName CountryCode  Year  Total GHG emissions (ktCO2e)  Projection
# 1       Germany         DEU  1990                   1160210.000           0
# 2       Belgium         BEL  1990                    130730.000           0
# 3        France         FRA  1990                    502750.000           0
# 4         Italy         ITA  1990                    491250.000           0
# 5    Luxembourg         LUX  1990                     12200.000           0
# ..          ...         ...   ...                           ...         ...
# 949       EU 27       EU 27  2036                   2097194.224           1
# 950       EU 27       EU 27  2037                   2062327.808           1
# 951       EU 27       EU 27  2038                   2026970.300           1
# 952       EU 27       EU 27  2039                   1950055.930           1
# 953       EU 27       EU 27  2040                   1916982.025           1
#
# [945 rows x 5 columns]

# %%
GHG_emissions_actual_and_proj['CountryCode'].unique()
# Out:
# array(['DEU', 'BEL', 'FRA', 'ITA', 'LUX', 'NLD', 'DNK', 'IRL', 'GRC',
#        'ESP', 'PRT', 'AUT', 'FIN', 'SWE', 'CYP', 'EST', 'HUN', 'LVA',
#        'LTU', 'MLT', 'POL', 'CZE', 'SVK', 'SVN', 'BGR', 'ROU', 'HRV',
#        'CHE', 'ISL', 'NOR', 'EU 27'], dtype=object)

# %%
GHG_emissions_actual_and_proj['CountryName']= GHG_emissions_actual_and_proj['CountryName'].str.upper()
# Out:
# C:\Users\Pablo\AppData\Local\Temp/ipykernel_23856/2820202989.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GHG_emissions_actual_and_proj['CountryName']= GHG_emissions_actual_and_proj['CountryName'].str.upper()

# %%
GHG_emissions_actual_and_proj
# Out:
#     CountryName CountryCode  Year  Total GHG emissions (ktCO2e)  Projection
# 1       GERMANY         DEU  1990                   1160210.000           0
# 2       BELGIUM         BEL  1990                    130730.000           0
# 3        FRANCE         FRA  1990                    502750.000           0
# 4         ITALY         ITA  1990                    491250.000           0
# 5    LUXEMBOURG         LUX  1990                     12200.000           0
# ..          ...         ...   ...                           ...         ...
# 949       EU 27       EU 27  2036                   2097194.224           1
# 950       EU 27       EU 27  2037                   2062327.808           1
# 951       EU 27       EU 27  2038                   2026970.300           1
# 952       EU 27       EU 27  2039                   1950055.930           1
# 953       EU 27       EU 27  2040                   1916982.025           1
#
# [945 rows x 5 columns]

# %%
GHG_emissions_actual_and_proj.to_csv('GHG_emissions_actual_and_proj.csv')
